# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd

# %%
df = pd.read_csv("data/clues.csv")

# %%
df[(df["source"]=="times_xwd_times")&(df["puzzle_name"].str.startswith("Times Quick Cryptic"))]
# Out:
#          rowid                                               clue     answer  \
# 87          88      Intrepid daughter missing parent's sister (9)  DAUNTLESS
# 88          89  Literary genre in South Carolina, one includin...        SCI
# 89          90       Training device transforming Liam's tour (9)  SIMULATOR
# 90          91                  Plant serving sauce with meat (5)      OXLIP
# 91          92          Clothing submerged in northern river? (9)  UNDERWEAR
# ...        ...                                                ...        ...
# 626975  630015                        Test area in former pit (7)    EXAMINE
# 626976  630016          Abroad, target a series of boat races (7)    REGATTA
# 626977  630017                        Tree in travel magazine (3)        ELM
# 626978  630018                     Pair in York perhaps binge (5)      SPREE
# 626979  630019                             Working until dark (5)      UNLIT
#
# ...

# %% [markdown]
# https://timesforthetimes.co.uk/times-quick-cryptic-2131-by-breadman-2

# %%
df[(df["source"]=="times_xwd_times")&(df["puzzle_name"].str.startswith("Times Quick Cryptic"))]
# Out:
#          rowid                                               clue     answer  \
# 87          88      Intrepid daughter missing parent's sister (9)  DAUNTLESS
# 88          89  Literary genre in South Carolina, one includin...        SCI
# 89          90       Training device transforming Liam's tour (9)  SIMULATOR
# 90          91                  Plant serving sauce with meat (5)      OXLIP
# 91          92          Clothing submerged in northern river? (9)  UNDERWEAR
# ...        ...                                                ...        ...
# 626975  630015                        Test area in former pit (7)    EXAMINE
# 626976  630016          Abroad, target a series of boat races (7)    REGATTA
# 626977  630017                        Tree in travel magazine (3)        ELM
# 626978  630018                     Pair in York perhaps binge (5)      SPREE
# 626979  630019                             Working until dark (5)      UNLIT
#
# ...

# %%
df[df["puzzle_name"]== "Times Quick Cryptic 1711"].to_csv("data/examples/qc_1711.csv", index=False)

# %%
df[(df["source"]=="times_xwd_times")&(df["puzzle_name"] == "Times Quick Cryptic 1711")]
# Out:
#      rowid                                               clue         answer  \
# 87      88      Intrepid daughter missing parent's sister (9)      DAUNTLESS
# 88      89  Literary genre in South Carolina, one includin...            SCI
# 89      90       Training device transforming Liam's tour (9)      SIMULATOR
# 90      91                  Plant serving sauce with meat (5)          OXLIP
# 91      92          Clothing submerged in northern river? (9)      UNDERWEAR
# 92      93                     Popular act, without doubt (6)         INDEED
# 93      94           Position of rubbish in South America (6)         STATUS
# 94      95  Element Mendeleev originally found in flowerin...      GERMANIUM
# 95      96      Head of police called, revealing accident (5)          PRANG
# 96      97                       Switch posts near ground (9)      TRANSPOSE
# 97      98  With cunning, son locates youth leaders twice (5)          SLYLY
# ...
