# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import functools
import pandas as pd
import re

from IPython.display import display

from cryptic.evaluation.evaluations import MetroQA
from cryptic.models.oai import OpenAIQA
from cryptic.models.selectors import SelfConsistencySelector
from cryptic.models.validators import SubWordConsistencyValidator
from cryptic.prompts.interface import PromptInterface

# %%
JSON_FILENAME = "website/crosswordData.json"
DUMMY_CLUE = "A farmer's son"
NUM_CLUES = None
NUM_ANSWERS = 10

# %% [markdown]
# Check that injection of clue and num letters into prompt template is working correctly:

# %%
prompt_interface = PromptInterface("cryptic.prompts.cot.ben_v1")
prompt = prompt_interface.inject_prompt(DUMMY_CLUE, 5)
print(prompt)
# Out:
# I will answer some clues:
#     1. Boy captures the work of Shakespeare, for example (7)
#     Answer: SONNETS (examples of works of Shakespeare) - SON (boy) + NETS (captures)
#     2. Country folk appearing in operatic piece (7)
#     Answer: ARMENIA (country) - ARIA (operatic piece) + MEN (folk)
#     3. Where men are on board ship beside revolutionary (5)
#     Answer: CHESS (where men are on board) - CHE (Revolutionary, Che Guevara) + SS (designation for a ship)
#     4. Amputate limbs to remove weapons (6)
#     Answer: DISARM (Remove weapons  - DIS-ARM (amputating limbs)
#     5. Accuse one politician apiece (7)
#     Answer: IMPEACH (accuse) - I (one) + MP (politician) + EACH (apiece)
#     6. Orchestra was taken aback by cutting machine (7)
#     Answer: BANDSAW (cutting machine) - BAND (orchestra) + SAW (was, 'taken aback' i.e. backwards)
#     7. Concerning drama in second game after draw (6)
#     Answer: REPLAY (a second game, typically following a drawn result in the first) - RE (meaning concerning) + PLAY (a type of drama)
#     Answer this clue in the same style, making sure not to give any verbal explanation, following 'Answer:'.
#
#     Clue: A farmer's son (5)

# %% [markdown]
# Check extraction of answer is working correctly

# %%
out = prompt_interface.prompt_templates["example_output"]

# %%
res = prompt_interface.extract_answer(out)
res
# Out:
# {'response': 'Answer: REPLAY (a second game, typically following a drawn result in the first) - RE (meaning concerning) + PLAY (a type of drama)',
#  'answer': 'REPLAY',
#  'predicted_definition': 'a second game, typically following a drawn result in the first',
#  'wordplay': 'RE (meaning concerning) + PLAY (a type of drama)'}

# %%
prompt_interface.decompose(res["wordplay"])
# Out:
# [{'answer': 'RE', 'definition': 'meaning concerning'},
#  {'answer': 'PLAY', 'definition': 'a type of drama'}]

# %%
validator = SubWordConsistencyValidator(prompt_interface)

# %%
evaluation = MetroQA(JSON_FILENAME, num_answers=NUM_ANSWERS, num_clues=NUM_CLUES)

# %%
model = OpenAIQA(
    prompt_interface=prompt_interface,
    model_name="text-davinci-003",
    max_tokens=64,
    validators=[validator],
    validator_names=["consistent_decomposition"]
)

# %%
df = evaluation.qa_frame.df
df.head(3)
# Out:
#                                                 clue  answer  startx  starty
# 0  Liquor of particular make needed by youth lead...  xxxxxx       1       1  \
# 1  Not the HQ of Britain's capital stockbreeding ...  xxxxxx       1       1
# 2               Amputate limbs to remove weapons (6)  xxxxxx       8       1
#
#    position orientation num_letters  rowid
# 0         1      across           6      0
# 1         1        down           6      1
# 2         4      across           6      2

# %% [markdown]
# First feed a single clue through the API to look at model output and check that we are correctly parsing responses.
#
# This might need to be tweaked: e.g. removal of newline / space chars etc,
# to convert into a standard answer format

# %%
clue, num_letters = evaluation.qa_frame.sample(1).df.iloc[0][["clue", "num_letters"]]

# %%
response = model.get_response(clue, num_letters, num_answers=2)
response
# Out:
# <OpenAIObject text_completion id=cmpl-759ubvbaXSAF8ZJ94cGGVGD8R21h3 at 0x10f0b0d60> JSON: {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": "\nAnswer: TRENDY (stylish) - TRY (trying) + END (in a way) + Y (way)."
#     },
#     {
#       "finish_reason": "stop",
#       "index": 1,
#       "logprobs": null,
#       "text": "\nAnswer: FASHIONABLE (trying to be stylish in a way) - FASH (in a way) + ION (stylish) + ABLE (trying)."
#     }
#   ],
#   "created": 1681464097,
#   "id": "cmpl-759ubvbaXSAF8ZJ94cGGVGD8R21h3",
#   "model": "text-davinci-003",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 68,
#     "prompt_tokens": 365,
#     "total_tokens": 433
#   }
# }

# %%
out = response["choices"][0]["text"]

# %%
res = prompt_interface.extract_answer(response["choices"][0]["text"])
res
# Out:
# {'response': '\nAnswer: TRENDY (stylish) - TRY (trying) + END (in a way) + Y (way).',
#  'answer': 'TRENDY',
#  'predicted_definition': 'stylish',
#  'wordplay': 'TRY (trying) + END (in a way) + Y (way).'}

# %%
prompt_interface.decompose(res["wordplay"])
# Out:
# [{'answer': 'TRY', 'definition': 'trying'},
#  {'answer': 'END', 'definition': 'in a way'},
#  {'answer': 'Y', 'definition': 'way'}]

# %%
validator.validate(res["answer"], res["predicted_definition"], res["wordplay"])
# Out:
# False

# %% [markdown]
# Once we're confident that answers are being extracted correctly we can run a whole set of clues through

# %%
metrics, answer_df = evaluation.run(model)
# Out:
# 24it [01:19,  3.31s/it]

# %%
model.validator_names
# Out:
# ['consistent_decomposition']

# %%
pred_cols = ["prediction", "predicted_definition", "wordplay"]
vis_cols = pred_cols + model.validator_names + ["prediction_satisfies_constraints"]

# %%
for i in range(NUM_ANSWERS):
    display(answer_df[["clue", "answer"] + [c + f"-{i}" for c in vis_cols]])
# Out:
#                                                  clue         answer
# 0   Liquor of particular make needed by youth lead...         xxxxxx  \
# 1   Not the HQ of Britain's capital stockbreeding ...         xxxxxx
# 2                Amputate limbs to remove weapons (6)         xxxxxx
# 3               Trying to be stylish in a way (5,1,7)  xxxxxyzzzzzzz
# 4             Temporary leader in dramatic game (6,7)  xxxxxxyyyyyyy
# 5                    Material that could be mined (5)          xxxxx
# 6            Sweetmeat of male injured by vehicle (7)        xxxxxxx
# 7                    Accuse one politician apiece (7)        xxxxxxx
# 8           Twitch before at the top of the house (5)          xxxxx
# 9                          A length being planned (5)          xxxxx
# 10                            No he's been bright (5)          xxxxx
# 11              As the change was made in a hurry (5)          xxxxx
# 12   Orchestra was taken aback by cutting machine (7)        xxxxxxx
# 13        Exuberance produced by beastly drink? (6,7)  xxxxxxyyyyyyy
# 14         Cause delay in the one nearer the back (6)         xxxxxx
# 15      Concering drama in second game after draw (6)         xxxxxx
# 16  Lands it at last so it's not moving at all (2,...  xxyzzzzzzzzzz
# 17               Threat to workers by one in suit (6)         xxxxxx
# 18                                  A noted climb (5)          xxxxx
# 19                       Make cuts in the theatre (7)        xxxxxxx
# 20    Woman with hat made to look like sword case (6)         xxxxxx
# 21                   Humiliate because in Lincoln (5)          xxxxx
# 22                       Not straight like Oliver (6)         xxxxxx
# 23                                   One is sound (5)          xxxxx
#
#    prediction-0                             predicted_definition-0
# 0     MOONSHINE                          liquor of particular make  \
# 1
# 2
# 3      PREENING                               trying to be stylish
# 4      INTERIMS                                   temporary leader
# 5
# 6       CANDIED                                          sweetmeat
# 7       IMPEACH                                             accuse
# 8         ATTIC                                   top of the house
# 9          SPAN                                           a length
# 10        SHINE                                             bright
# 11        SCRAM                  as the change was made in a hurry
# 12      BANDSAW                                    cutting machine
# 13      GINFIZZ                                         exuberance
# 14       HOLDUP                                        cause delay
# 15       REPLAY  a second game, typically following a drawn res...
# 16       SETSIN         lands it at last so it's not moving at all
# 17       STRIKE                                  threat to workers
# 18       ASCENT                                      a noted climb
# 19      TRIMMER                                          make cuts
# 20     SCABBARD                                         sword case
# 21        ABASE                                          humiliate
# 22      CROOKED                                       not straight
# 23        AUDIO                                       one is sound
#
#                                            wordplay-0
# 0                MOON (youth leader) + SHINE (needed)  \
# 1
# 2
# 3                   PREEN (in a way) + IN + G (style)
# 4                INTER (dramatic game) + IMS (leader)
# 5
# 6              CAND (male) + IED (injured by vehicle)
# 7           I (one) + MP (politician) + EACH (apiece)
# 8                          AT (before) + TIC (twitch)
# 9                           S (being) + PAN (planned)
# 10                               HE'S (no) + N (been)
# 11                          SCR (hurry) + AM (change)
# 12  BAND (orchestra) + SAW (was, 'taken aback' i.e...
# 13              GIN (beastly drink) + FIZZ (produced)
# 14  HO (the one nearer the back) + LD (back) + UP ...
# 15  RE (meaning concerning) + PLAY (a type of drama).
# 16                   SET (not moving) + SIN (at last)
# 17  I (one) + ST (suit) + RKE (threat, 'to' backwa...
# 18                             A (an) + SCENT (climb)
# 19                   TRIM (theatre) + MER (make cuts)
# 20  SCAR (woman) + B (hat) + BARD (made to look like)
# 21                       A (because) + BASE (Lincoln)
# 22   CROOK (like Oliver) + ED (suffix meaning 'like')
# 23                             A (one) + UDIO (sound)
#
#     consistent_decomposition-0  prediction_satisfies_constraints-0
# 0                         True                               False
# 1                         True                               False
# 2                         True                               False
# 3                        False                               False
# 4                         True                               False
# 5                         True                               False
# 6                         True                                True
# 7                         True                                True
# 8                         True                                True
# 9                         True                               False
# 10                       False                               False
# 11                        True                                True
# 12                        True                                True
# 13                        True                               False
# 14                        True                                True
# 15                        True                                True
# 16                        True                               False
# 17                        True                                True
# 18                        True                               False
# 19                        True                                True
# 20                       False                               False
# 21                        True                                True
# 22                        True                               False
# 23                        True                                True
#                                                  clue         answer
# 0   Liquor of particular make needed by youth lead...         xxxxxx  \
# 1   Not the HQ of Britain's capital stockbreeding ...         xxxxxx
# 2                Amputate limbs to remove weapons (6)         xxxxxx
# 3               Trying to be stylish in a way (5,1,7)  xxxxxyzzzzzzz
# 4             Temporary leader in dramatic game (6,7)  xxxxxxyyyyyyy
# 5                    Material that could be mined (5)          xxxxx
# 6            Sweetmeat of male injured by vehicle (7)        xxxxxxx
# 7                    Accuse one politician apiece (7)        xxxxxxx
# 8           Twitch before at the top of the house (5)          xxxxx
# 9                          A length being planned (5)          xxxxx
# 10                            No he's been bright (5)          xxxxx
# 11              As the change was made in a hurry (5)          xxxxx
# 12   Orchestra was taken aback by cutting machine (7)        xxxxxxx
# 13        Exuberance produced by beastly drink? (6,7)  xxxxxxyyyyyyy
# 14         Cause delay in the one nearer the back (6)         xxxxxx
# 15      Concering drama in second game after draw (6)         xxxxxx
# 16  Lands it at last so it's not moving at all (2,...  xxyzzzzzzzzzz
# 17               Threat to workers by one in suit (6)         xxxxxx
# 18                                  A noted climb (5)          xxxxx
# 19                       Make cuts in the theatre (7)        xxxxxxx
# 20    Woman with hat made to look like sword case (6)         xxxxxx
# 21                   Humiliate because in Lincoln (5)          xxxxx
# 22                       Not straight like Oliver (6)         xxxxxx
# 23                                   One is sound (5)          xxxxx
#
#    prediction-1                             predicted_definition-1
# 0        MOJITO                                             liquor  \
# 1
# 2
# 3      VOGUEING                               trying to be stylish
# 4      INTERIMS                                   temporary leader
# 5         OREAL                       material that could be mined
# 6       CANDIES                                          sweetmeat
# 7       IMPEACH                                             accuse
# 8         ATTIC                                   top of the house
# 9          SPAN                                           a length
# 10        SHINE                                             bright
# 11       RUSHED                                    made in a hurry
# 12      BANDSAW                                    cutting machine
# 13    ANIMALCUP                                      beastly drink
# 14       HOLDUP                                        cause delay
# 15       REPLAY  a second game, typically following a drawn res...
# 16      SETS IN         lands it at last so it's not moving at all
# 17       LAYOFF                                  threat to workers
# 18       ASCENT                                      a noted climb
# 19      PRUNING                                          make cuts
# 20
# 21        ABASE                                          humiliate
# 22      CROOKED                                       not straight
# 23
#
#                                            wordplay-1
# 0     MO (make) + JIT (youth leader) + O (particular)  \
# 1
# 2
# 3                     VOGUE (in a way) + ING (trying)
# 4                       INT (dramatic) + ERIMS (game)
# 5                ORE (mined material) + AL (could be)
# 6                 CAN (vehicle) + DIES (male injured)
# 7           I (one) + MP (politician) + EACH (apiece)
# 8                          AT (before) + TIC (twitch)
# 9                           S (being) + PAN (planned)
# 10                               HE'S (no) + N (none)
# 11                           RUSH (change) + ED (was)
# 12  BAND (orchestra) + SAW (was, 'taken aback' i.e...
# 13               ANIMAL (exuberance) + CUP (produced)
# 14                  HOLD (one) + UP (nearer the back)
# 15   RE (meaning concerning) + PLAY (a type of drama)
# 16                  SET (it) + SIN (at last) + T (so)
# 17     LAY (one in suit, i.e. an employee) + OFF (by)
# 18                            A (the) + Scent (climb)
# 19                           RUN (theatre) + ING (in)
# 20
# 21                    A (because) + BASE (in Lincoln)
# 22                         CROOK (Oliver) + ED (like)
# 23
#
#     consistent_decomposition-1  prediction_satisfies_constraints-1
# 0                         True                                True
# 1                         True                               False
# 2                         True                               False
# 3                         True                               False
# 4                         True                               False
# 5                         True                                True
# 6                         True                                True
# 7                         True                                True
# 8                         True                                True
# 9                         True                               False
# 10                       False                               False
# 11                        True                               False
# 12                        True                                True
# 13                        True                               False
# 14                        True                                True
# 15                        True                                True
# 16                       False                               False
# 17                        True                                True
# 18                       False                               False
# 19                       False                                True
# 20                        True                               False
# 21                        True                                True
# 22                        True                               False
# 23                        True                               False
#                                                  clue         answer
# 0   Liquor of particular make needed by youth lead...         xxxxxx  \
# 1   Not the HQ of Britain's capital stockbreeding ...         xxxxxx
# 2                Amputate limbs to remove weapons (6)         xxxxxx
# 3               Trying to be stylish in a way (5,1,7)  xxxxxyzzzzzzz
# 4             Temporary leader in dramatic game (6,7)  xxxxxxyyyyyyy
# 5                    Material that could be mined (5)          xxxxx
# 6            Sweetmeat of male injured by vehicle (7)        xxxxxxx
# 7                    Accuse one politician apiece (7)        xxxxxxx
# 8           Twitch before at the top of the house (5)          xxxxx
# 9                          A length being planned (5)          xxxxx
# 10                            No he's been bright (5)          xxxxx
# 11              As the change was made in a hurry (5)          xxxxx
# 12   Orchestra was taken aback by cutting machine (7)        xxxxxxx
# 13        Exuberance produced by beastly drink? (6,7)  xxxxxxyyyyyyy
# 14         Cause delay in the one nearer the back (6)         xxxxxx
# 15      Concering drama in second game after draw (6)         xxxxxx
# 16  Lands it at last so it's not moving at all (2,...  xxyzzzzzzzzzz
# 17               Threat to workers by one in suit (6)         xxxxxx
# 18                                  A noted climb (5)          xxxxx
# 19                       Make cuts in the theatre (7)        xxxxxxx
# 20    Woman with hat made to look like sword case (6)         xxxxxx
# 21                   Humiliate because in Lincoln (5)          xxxxx
# 22                       Not straight like Oliver (6)         xxxxxx
# 23                                   One is sound (5)          xxxxx
#
#    prediction-2                             predicted_definition-2
# 0        TEENER                                       youth leader  \
# 1       POULTRY                               stockbreeding centre
# 2
# 3   FASHIONABLE                      trying to be stylish in a way
# 4
# 5
# 6       CARAMEL                                          sweetmeat
# 7       IMPEACH                                             accuse
# 8         ATTIC                                   top of the house
# 9          SPAN                                           a length
# 10
# 11       SWAPIT                             change made in a hurry
# 12      BANDSAW                                    cutting machine
# 13      GINFEST                                         exuberance
# 14       HOLDUP                                        cause delay
# 15       REPLAY  a second game, typically following a drawn res...
# 16       SETTLE                                   lands it at last
# 17       STRIKE                                  threat to workers
# 18       ASCENT                                      a noted climb
# 19     TRIMMING                                          make cuts
# 20       SHEATH                   hat made to look like sword case
# 21        ABASE                                          humiliate
# 22      CROOKED                                       not straight
# 23        AUDIO                                       one is sound
#
#                                            wordplay-2
# 0   TEEN (youth) + ER (make, as in brand or manufa...  \
# 1      HQ (headquarters) + LONDON (Britain's capital)
# 2
# 3                  FASHION (in a way) + ABLE (trying)
# 4
# 5
# 6           CAR (vehicle) + MEL (male) - EL (injured)
# 7           I (one) + MP (politician) + EACH (apiece)
# 8                          AT (Twitch) + TIC (before)
# 9                           S (being) + PAN (planned)
# 10
# 11                    SWAP (change) + IT (in a hurry)
# 12  BAND (orchestra) + SAW (was, 'taken aback' i.e...
# 13              GIN (beastly drink) + FEST (produced)
# 14              HOLD (the one) + UP (nearer the back)
# 15   RE (meaning concerning) + PLAY (a type of drama)
# 16            SET (so it's not moving) + TLE (at all)
# 17                             S (one) + TRIKE (suit)
# 18                              A (a) + SCENT (climb)
# 19                         TRIM (theatre) + MING (in)
# 20                           SHE (woman) + ATH (made)
# 21                BE (because) + A (in) + S (Lincoln)
# 22   COOK (like Oliver Twist's surname) + ED (suffix)
# 23                             A (one) + UDIO (sound)
#
#     consistent_decomposition-2  prediction_satisfies_constraints-2
# 0                         True                                True
# 1                        False                               False
# 2                         True                               False
# 3                         True                               False
# 4                         True                               False
# 5                         True                               False
# 6                        False                                True
# 7                         True                                True
# 8                         True                                True
# 9                         True                               False
# 10                        True                               False
# 11                        True                               False
# 12                        True                                True
# 13                        True                               False
# 14                        True                                True
# 15                        True                                True
# 16                        True                               False
# 17                        True                                True
# 18                        True                               False
# 19                        True                               False
# 20                        True                                True
# 21                       False                                True
# 22                       False                               False
# 23                        True                                True
#                                                  clue         answer
# 0   Liquor of particular make needed by youth lead...         xxxxxx  \
# 1   Not the HQ of Britain's capital stockbreeding ...         xxxxxx
# 2                Amputate limbs to remove weapons (6)         xxxxxx
# 3               Trying to be stylish in a way (5,1,7)  xxxxxyzzzzzzz
# 4             Temporary leader in dramatic game (6,7)  xxxxxxyyyyyyy
# 5                    Material that could be mined (5)          xxxxx
# 6            Sweetmeat of male injured by vehicle (7)        xxxxxxx
# 7                    Accuse one politician apiece (7)        xxxxxxx
# 8           Twitch before at the top of the house (5)          xxxxx
# 9                          A length being planned (5)          xxxxx
# 10                            No he's been bright (5)          xxxxx
# 11              As the change was made in a hurry (5)          xxxxx
# 12   Orchestra was taken aback by cutting machine (7)        xxxxxxx
# 13        Exuberance produced by beastly drink? (6,7)  xxxxxxyyyyyyy
# 14         Cause delay in the one nearer the back (6)         xxxxxx
# 15      Concering drama in second game after draw (6)         xxxxxx
# 16  Lands it at last so it's not moving at all (2,...  xxyzzzzzzzzzz
# 17               Threat to workers by one in suit (6)         xxxxxx
# 18                                  A noted climb (5)          xxxxx
# 19                       Make cuts in the theatre (7)        xxxxxxx
# 20    Woman with hat made to look like sword case (6)         xxxxxx
# 21                   Humiliate because in Lincoln (5)          xxxxx
# 22                       Not straight like Oliver (6)         xxxxxx
# 23                                   One is sound (5)          xxxxx
#
#    prediction-3                             predicted_definition-3
# 0        BRANDY                                             liquor  \
# 1
# 2
# 3   FASHIONABLE                      trying to be stylish in a way
# 4       INTERIM                                   temporary leader
# 5
# 6       CANDIES                                          sweetmeat
# 7       IMPEACH                                             accuse
# 8
# 9          SPAN                                           a length
# 10
# 11       RUSHED                             change made in a hurry
# 12      BANDSAW                                    cutting machine
# 13      GINRUSH                                         exuberance
# 14       HOLDUP                                        cause delay
# 15       REPLAY  a second game, typically following a drawn res...
# 16       SETTLE                                   lands it at last
# 17       STRIKE                                  threat to workers
# 18       ASCENT                                      a noted climb
# 19      TRIMMER                                          make cuts
# 20     SCABBARD                                         sword case
# 21        ABASE                                          humiliate
# 22      CROOKED                                       not straight
# 23
#
#                                            wordplay-3
# 0   BRAN (youth leader) + DY (make, as in a partic...  \
# 1
# 2
# 3    FASH (in a way) + ION (trying) + ABLE (stylish).
# 4                     INTER (dramatic game) + IM (in)
# 5
# 6   CAN (vehicle) + DIES (male, past tense of 'die...
# 7           I (one) + MP (politician) + EACH (apiece)
# 8
# 9                          S (being) + PLAN (planned)
# 10
# 11                       RUSH (as, 'was') + ED (made)
# 12  BAND (orchestra) + SAW (was, 'taken aback' i.e...
# 13              GIN (beastly drink) + RUSH (produced)
# 14      HOLD (the one nearer the back) + UP (nearby).
# 15   RE (meaning concerning) + PLAY (a type of drama)
# 16            SET (so it's not moving) + TLE (at all)
# 17                             S (one) + TRIKE (suit)
# 18                              A (a) + SCENT (climb)
# 19                          TRI (theatre) + MMER (in)
# 20         SCAR (woman) + BARD (hat, as in 'top hat')
# 21  A (because) + BASE (Lincoln, i.e. a base in Li...
# 22                  CROOK (like Oliver) + ED (suffix)
# 23
#
#     consistent_decomposition-3  prediction_satisfies_constraints-3
# 0                         True                                True
# 1                         True                               False
# 2                         True                               False
# 3                         True                               False
# 4                         True                               False
# 5                         True                               False
# 6                        False                                True
# 7                         True                                True
# 8                         True                               False
# 9                        False                               False
# 10                        True                               False
# 11                        True                               False
# 12                        True                                True
# 13                        True                               False
# 14                        True                                True
# 15                        True                                True
# 16                        True                               False
# 17                        True                                True
# 18                        True                               False
# 19                        True                                True
# 20                       False                               False
# 21                        True                                True
# 22                        True                               False
# 23                        True                               False
#                                                  clue         answer
# 0   Liquor of particular make needed by youth lead...         xxxxxx  \
# 1   Not the HQ of Britain's capital stockbreeding ...         xxxxxx
# 2                Amputate limbs to remove weapons (6)         xxxxxx
# 3               Trying to be stylish in a way (5,1,7)  xxxxxyzzzzzzz
# 4             Temporary leader in dramatic game (6,7)  xxxxxxyyyyyyy
# 5                    Material that could be mined (5)          xxxxx
# 6            Sweetmeat of male injured by vehicle (7)        xxxxxxx
# 7                    Accuse one politician apiece (7)        xxxxxxx
# 8           Twitch before at the top of the house (5)          xxxxx
# 9                          A length being planned (5)          xxxxx
# 10                            No he's been bright (5)          xxxxx
# 11              As the change was made in a hurry (5)          xxxxx
# 12   Orchestra was taken aback by cutting machine (7)        xxxxxxx
# 13        Exuberance produced by beastly drink? (6,7)  xxxxxxyyyyyyy
# 14         Cause delay in the one nearer the back (6)         xxxxxx
# 15      Concering drama in second game after draw (6)         xxxxxx
# 16  Lands it at last so it's not moving at all (2,...  xxyzzzzzzzzzz
# 17               Threat to workers by one in suit (6)         xxxxxx
# 18                                  A noted climb (5)          xxxxx
# 19                       Make cuts in the theatre (7)        xxxxxxx
# 20    Woman with hat made to look like sword case (6)         xxxxxx
# 21                   Humiliate because in Lincoln (5)          xxxxx
# 22                       Not straight like Oliver (6)         xxxxxx
# 23                                   One is sound (5)          xxxxx
#
#      prediction-4                             predicted_definition-4
# 0          MALTED                                             liquor  \
# 1
# 2
# 3
# 4        INTERIMS                                   temporary leader
# 5
# 6          BONBON                                          sweetmeat
# 7         IMPEACH                                             accuse
# 8           ATTIC                                   top of the house
# 9            SPAN                                           a length
# 10          SHINE                                No he's been bright
# 11         SWAPIT                             change made in a hurry
# 12        BANDSAW                                    cutting machine
# 13  ANIMAL SPIRIT                                         exuberance
# 14         HOLDUP                                        cause delay
# 15         REPLAY  a second game, typically following a drawn res...
# 16
# 17         STRIKE                                  threat to workers
# 18         ASCENT                                      a noted climb
# 19        TRIMMER                                          make cuts
# 20         SHEATH                   hat made to look like sword case
# 21          ABASE                                          humiliate
# 22        CROOKED                                       not straight
# 23
#
#                                            wordplay-4
# 0   MADE (particular make) + LT (youth leader, Lie...  \
# 1
# 2
# 3
# 4                INTER (dramatic game) + IMS (leader)
# 5
# 6            BON (male) + BON (injured) + V (vehicle)
# 7           I (one) + MP (politician) + EACH (apiece)
# 8          AT (Twitch, as in the verb) + TIC (before)
# 9                           S (being) + PAN (planned)
# 10                        SH (none) + INE (he's been)
# 11                       SWAP (as) + IT (in a hurry).
# 12  BAND (orchestra) + SAW (was, 'taken aback' i.e...
# 13                  ANIMAL (beastly) + SPIRIT (drink)
# 14     HOLD (the one nearer the back) + UP (the back)
# 15   RE (meaning concerning) + PLAY (a type of drama)
# 16
# 17                             S (one) + TRIKE (suit)
# 18                              A (a) + SCENT (climb)
# 19                          TRI (theatre) + MMER (in)
# 20              SHE (woman) + ATH (made to look like)
# 21   A (because) + BASE (Lincoln, a US military base)
# 22                         CROOK (Oliver) + ED (like)
# 23
#
#     consistent_decomposition-4  prediction_satisfies_constraints-4
# 0                         True                                True
# 1                         True                               False
# 2                         True                               False
# 3                         True                               False
# 4                         True                               False
# 5                         True                               False
# 6                        False                               False
# 7                         True                                True
# 8                         True                                True
# 9                         True                               False
# 10                        True                               False
# 11                        True                               False
# 12                        True                                True
# 13                       False                               False
# 14                        True                                True
# 15                        True                                True
# 16                        True                               False
# 17                        True                                True
# 18                        True                               False
# 19                        True                                True
# 20                        True                                True
# 21                        True                                True
# 22                        True                               False
# 23                        True                               False
#                                                  clue         answer
# 0   Liquor of particular make needed by youth lead...         xxxxxx  \
# 1   Not the HQ of Britain's capital stockbreeding ...         xxxxxx
# 2                Amputate limbs to remove weapons (6)         xxxxxx
# 3               Trying to be stylish in a way (5,1,7)  xxxxxyzzzzzzz
# 4             Temporary leader in dramatic game (6,7)  xxxxxxyyyyyyy
# 5                    Material that could be mined (5)          xxxxx
# 6            Sweetmeat of male injured by vehicle (7)        xxxxxxx
# 7                    Accuse one politician apiece (7)        xxxxxxx
# 8           Twitch before at the top of the house (5)          xxxxx
# 9                          A length being planned (5)          xxxxx
# 10                            No he's been bright (5)          xxxxx
# 11              As the change was made in a hurry (5)          xxxxx
# 12   Orchestra was taken aback by cutting machine (7)        xxxxxxx
# 13        Exuberance produced by beastly drink? (6,7)  xxxxxxyyyyyyy
# 14         Cause delay in the one nearer the back (6)         xxxxxx
# 15      Concering drama in second game after draw (6)         xxxxxx
# 16  Lands it at last so it's not moving at all (2,...  xxyzzzzzzzzzz
# 17               Threat to workers by one in suit (6)         xxxxxx
# 18                                  A noted climb (5)          xxxxx
# 19                       Make cuts in the theatre (7)        xxxxxxx
# 20    Woman with hat made to look like sword case (6)         xxxxxx
# 21                   Humiliate because in Lincoln (5)          xxxxx
# 22                       Not straight like Oliver (6)         xxxxxx
# 23                                   One is sound (5)          xxxxx
#
#     prediction-5                             predicted_definition-5
# 0         BRANDY                                             liquor  \
# 1         LIVERY  not the HQ of Britain's capital stockbreeding ...
# 2
# 3       PREENING                               trying to be stylish
# 4
# 5
# 6        CANDIES                                          sweetmeat
# 7        IMPEACH                                             accuse
# 8          ROOFT                                   top of the house
# 9           SPAN                                             length
# 10         SHINE                                             bright
# 11
# 12       BANDSAW                                    cutting machine
# 13  ANIMALSPIRIT                                         exuberance
# 14        HOLDUP                                        cause delay
# 15        REPLAY  a second game, typically following a drawn res...
# 16       SETS IN         lands it at last so it's not moving at all
# 17        LAYOFF                                  threat to workers
# 18        ASCENT                                      a noted climb
# 19       TRIMMER                                          make cuts
# 20
# 21         ABASE                                          humiliate
# 22       CROOKED                                       not straight
# 23         AUDIO                                              sound
#
#                                            wordplay-5
# 0   BR (abbreviation for 'youth leader', Boy/Girl ...  \
# 1                                LI (not) + VERY (HQ)
# 2
# 3                     PRE (in a way) + ENING (trying)
# 4
# 5
# 6                 CAN (vehicle) + DIES (male injured)
# 7           I (one) + MP (politician) + EACH (apiece)
# 8                          RT (twitch) + OOF (before)
# 9                          S (being) + PLAN (planned)
# 10                       HE'S (no he's) + NONE (been)
# 11
# 12  BAND (orchestra) + SAW (was, 'taken aback' i.e...
# 13                  ANIMAL (beastly) + SPIRIT (drink)
# 14  HO (the one nearer the back) + LD (the one nea...
# 15   RE (meaning concerning) + PLAY (a type of drama)
# 16            SET (not moving at all) + SIN (at last)
# 17      LAY (one in a suit, as in a court) + OFF (by)
# 18                              A (a) + SCENT (climb)
# 19                          TRI (theatre) + MMER (in)
# 20
# 21                       A (because) + BASE (Lincoln)
# 22                           O (Oliver) + OKED (like)
# 23                                A (one) + UDIO (is)
#
#     consistent_decomposition-5  prediction_satisfies_constraints-5
# 0                        False                                True
# 1                         True                                True
# 2                         True                               False
# 3                         True                               False
# 4                         True                               False
# 5                         True                               False
# 6                         True                                True
# 7                         True                                True
# 8                         True                                True
# 9                        False                               False
# 10                       False                               False
# 11                        True                               False
# 12                        True                                True
# 13                        True                               False
# 14                        True                                True
# 15                        True                                True
# 16                       False                               False
# 17                        True                                True
# 18                        True                               False
# 19                        True                                True
# 20                        True                               False
# 21                        True                                True
# 22                       False                               False
# 23                        True                                True
#                                                  clue         answer
# 0   Liquor of particular make needed by youth lead...         xxxxxx  \
# 1   Not the HQ of Britain's capital stockbreeding ...         xxxxxx
# 2                Amputate limbs to remove weapons (6)         xxxxxx
# 3               Trying to be stylish in a way (5,1,7)  xxxxxyzzzzzzz
# 4             Temporary leader in dramatic game (6,7)  xxxxxxyyyyyyy
# 5                    Material that could be mined (5)          xxxxx
# 6            Sweetmeat of male injured by vehicle (7)        xxxxxxx
# 7                    Accuse one politician apiece (7)        xxxxxxx
# 8           Twitch before at the top of the house (5)          xxxxx
# 9                          A length being planned (5)          xxxxx
# 10                            No he's been bright (5)          xxxxx
# 11              As the change was made in a hurry (5)          xxxxx
# 12   Orchestra was taken aback by cutting machine (7)        xxxxxxx
# 13        Exuberance produced by beastly drink? (6,7)  xxxxxxyyyyyyy
# 14         Cause delay in the one nearer the back (6)         xxxxxx
# 15      Concering drama in second game after draw (6)         xxxxxx
# 16  Lands it at last so it's not moving at all (2,...  xxyzzzzzzzzzz
# 17               Threat to workers by one in suit (6)         xxxxxx
# 18                                  A noted climb (5)          xxxxx
# 19                       Make cuts in the theatre (7)        xxxxxxx
# 20    Woman with hat made to look like sword case (6)         xxxxxx
# 21                   Humiliate because in Lincoln (5)          xxxxx
# 22                       Not straight like Oliver (6)         xxxxxx
# 23                                   One is sound (5)          xxxxx
#
#     prediction-6                             predicted_definition-6
# 0         BRANDY                                             liquor  \
# 1         LIVERY                    not the HQ of Britain's capital
# 2
# 3
# 4       INTERIMS                                   temporary leader
# 5
# 6       MARZIPAN                                          sweetmeat
# 7        IMPEACH                                             accuse
# 8          ROOFT                                   top of the house
# 9           SPAN                                             length
# 10
# 11        SWAPIT                             change made in a hurry
# 12       BANDSAW                                    cutting machine
# 13  ANIMALSPIRIT                                         exuberance
# 14        HOLDUP                                      cause a delay
# 15        REPLAY  a second game, typically following a drawn res...
# 16     STAYS PUT         lands it at last so it's not moving at all
# 17        LAYOFF                                  threat to workers
# 18        ASCENT                                      a noted climb
# 19       TRIMMER                                          make cuts
# 20        SHEATH                                         sword case
# 21         ABASE                                          humiliate
# 22       CROOKED                                       not straight
# 23
#
#                                            wordplay-6
# 0          BRAND (particular make) + Y (youth leader)  \
# 1              LI (stockbreeding centre) + VERY (not)
# 2
# 3
# 4                       INTER (dramatic) + IMS (game)
# 5
# 6   MAN (male) + RZ (injured by vehicle, i.e. 'RZ'...
# 7           I (one) + MP (politician) + EACH (apiece)
# 8    OOF (Twitch, backwards) + RT (Before, backwards)
# 9                          S (being) + PLAN (planned)
# 10
# 11                        SWAP (as) + IT (in a hurry)
# 12  BAND (orchestra) + SAW (was, 'taken aback' i.e...
# 13                  ANIMAL (beastly) + SPIRIT (drink)
# 14  HOLD (the one nearer the back) + UP (near the ...
# 15   RE (meaning concerning) + PLAY (a type of drama)
# 16                      STAYS (lands) + PUT (at last)
# 17        LAY (one in suit, i.e. a lawyer) + OFF (by)
# 18         A (the indefinite article) + SCENT (climb)
# 19                          TRI (theatre) + MMER (in)
# 20         SHE (woman) + ATH (hat, made to look like)
# 21                       A (because) + BASE (Lincoln)
# 22                         CROOK (Oliver) + ED (like)
# 23
#
#     consistent_decomposition-6  prediction_satisfies_constraints-6
# 0                         True                                True
# 1                         True                                True
# 2                         True                               False
# 3                         True                               False
# 4                         True                               False
# 5                         True                               False
# 6                        False                               False
# 7                         True                                True
# 8                         True                                True
# 9                        False                               False
# 10                        True                               False
# 11                        True                               False
# 12                        True                                True
# 13                        True                               False
# 14                        True                                True
# 15                        True                                True
# 16                       False                               False
# 17                        True                                True
# 18                        True                               False
# 19                        True                                True
# 20                        True                                True
# 21                        True                                True
# 22                        True                               False
# 23                        True                               False
#                                                  clue         answer
# 0   Liquor of particular make needed by youth lead...         xxxxxx  \
# 1   Not the HQ of Britain's capital stockbreeding ...         xxxxxx
# 2                Amputate limbs to remove weapons (6)         xxxxxx
# 3               Trying to be stylish in a way (5,1,7)  xxxxxyzzzzzzz
# 4             Temporary leader in dramatic game (6,7)  xxxxxxyyyyyyy
# 5                    Material that could be mined (5)          xxxxx
# 6            Sweetmeat of male injured by vehicle (7)        xxxxxxx
# 7                    Accuse one politician apiece (7)        xxxxxxx
# 8           Twitch before at the top of the house (5)          xxxxx
# 9                          A length being planned (5)          xxxxx
# 10                            No he's been bright (5)          xxxxx
# 11              As the change was made in a hurry (5)          xxxxx
# ...
# 10
# 11                    SWAP (change) + IT (in a hurry)
# 12  BAND (orchestra) + SAW (was, 'taken aback' i.e...
# 13                     ANIMAL (beastly) + ISM (drink)
# 14         HI (the one nearer the back) + NDER (back)
# 15   RE (meaning concerning) + PLAY (a type of drama)
# 16                   SET (not moving) + TLE (at all).
# 17
# 18                             A (an) + SCENT (climb)
# 19                          TRI (theatre) + MMER (in)
# 20              SHE (woman) + ATH (made to look like)
# 21                       A (because) + BASE (Lincoln)
# 22           COOKED (like Oliver, as in Oliver Twist)
# 23
#
#     consistent_decomposition-7  prediction_satisfies_constraints-7
# 0                         True                               False
# 1                         True                               False
# 2                         True                               False
# 3                         True                               False
# 4                         True                               False
# 5                         True                               False
# 6                         True                               False
# 7                         True                                True
# 8                         True                               False
# 9                         True                               False
# 10                        True                               False
# 11                        True                               False
# 12                        True                                True
# 13                        True                               False
# 14                        True                                True
# 15                        True                                True
# 16                        True                               False
# 17                        True                               False
# 18                        True                               False
# 19                        True                                True
# 20                        True                                True
# 21                        True                                True
# 22                       False                               False
# 23                        True                               False
#                                                  clue         answer
# 0   Liquor of particular make needed by youth lead...         xxxxxx  \
# 1   Not the HQ of Britain's capital stockbreeding ...         xxxxxx
# 2                Amputate limbs to remove weapons (6)         xxxxxx
# 3               Trying to be stylish in a way (5,1,7)  xxxxxyzzzzzzz
# 4             Temporary leader in dramatic game (6,7)  xxxxxxyyyyyyy
# 5                    Material that could be mined (5)          xxxxx
# 6            Sweetmeat of male injured by vehicle (7)        xxxxxxx
# 7                    Accuse one politician apiece (7)        xxxxxxx
# 8           Twitch before at the top of the house (5)          xxxxx
# 9                          A length being planned (5)          xxxxx
# 10                            No he's been bright (5)          xxxxx
# 11              As the change was made in a hurry (5)          xxxxx
# 12   Orchestra was taken aback by cutting machine (7)        xxxxxxx
# 13        Exuberance produced by beastly drink? (6,7)  xxxxxxyyyyyyy
# 14         Cause delay in the one nearer the back (6)         xxxxxx
# 15      Concering drama in second game after draw (6)         xxxxxx
# 16  Lands it at last so it's not moving at all (2,...  xxyzzzzzzzzzz
# 17               Threat to workers by one in suit (6)         xxxxxx
# 18                                  A noted climb (5)          xxxxx
# 19                       Make cuts in the theatre (7)        xxxxxxx
# 20    Woman with hat made to look like sword case (6)         xxxxxx
# 21                   Humiliate because in Lincoln (5)          xxxxx
# 22                       Not straight like Oliver (6)         xxxxxx
# 23                                   One is sound (5)          xxxxx
#
#    prediction-8                             predicted_definition-8
# 0        BRANDY                                             liquor  \
# 1
# 2
# 3      PREENING                               trying to be stylish
# 4      INTERIMP                                   Temporary leader
# 5
# 6      MARMALAD                                          sweetmeat
# 7       IMPEACH                                             accuse
# 8
# 9        SCHEME                             a length being planned
# 10
# 11
# 12      BANDSAW                                    cutting machine
# 13      GINFIZZ                                         exuberance
# 14       HINDER                                        cause delay
# 15       REPLAY  a second game, typically following a drawn res...
# 16      SETS IN         lands it at last so it's not moving at all
# 17       LAYOFF                                  threat to workers
# 18       ASCENT                                      a noted climb
# 19      TRIMMER                                          make cuts
# 20     SCABBARD                                         sword case
# 21        ABASE                                          humiliate
# 22      CROOKED                                       not straight
# 23
#
#                                            wordplay-8
# 0          BRAND (particular make) + Y (youth leader)  \
# 1
# 2
# 3                     PREEN (in a way) + ING (suffix)
# 4                    INTER (in) + IMP (dramatic game)
# 5
# 6           MAL (male) + AD (vehicle) + ARM (injured)
# 7           I (one) + MP (politician) + EACH (apiece)
# 8
# 9                SCHE (a length) + ME (being planned)
# 10
# 11
# 12  BAND (orchestra) + SAW (was, 'taken aback' i.e...
# 13              GIN (beastly drink) + FIZZ (produced)
# 14              HI (the one) + NDER (nearer the back)
# 15   RE (meaning concerning) + PLAY (a type of drama)
# 16                   SET (not moving) + SIN (at last)
# 17          LAY (by one, as in 'layman') + OFF (suit)
# 18                             A (an) + SCENT (climb)
# 19                          TRI (theatre) + MMER (in)
# 20            SCAB (woman) + BARD (made to look like)
# 21                       A (because) + BASE (Lincoln)
# 22                         CROOK (Oliver) + ED (like)
# 23
#
#     consistent_decomposition-8  prediction_satisfies_constraints-8
# 0                         True                                True
# 1                         True                               False
# 2                         True                               False
# 3                         True                               False
# 4                         True                               False
# 5                         True                               False
# 6                         True                               False
# 7                         True                                True
# 8                         True                               False
# 9                         True                               False
# 10                        True                               False
# 11                        True                               False
# 12                        True                                True
# 13                        True                               False
# 14                        True                                True
# 15                        True                                True
# 16                       False                               False
# 17                        True                                True
# 18                        True                               False
# 19                        True                                True
# 20                        True                               False
# 21                        True                                True
# 22                        True                               False
# 23                        True                               False
#                                                  clue         answer
# 0   Liquor of particular make needed by youth lead...         xxxxxx  \
# 1   Not the HQ of Britain's capital stockbreeding ...         xxxxxx
# 2                Amputate limbs to remove weapons (6)         xxxxxx
# 3               Trying to be stylish in a way (5,1,7)  xxxxxyzzzzzzz
# 4             Temporary leader in dramatic game (6,7)  xxxxxxyyyyyyy
# 5                    Material that could be mined (5)          xxxxx
# 6            Sweetmeat of male injured by vehicle (7)        xxxxxxx
# 7                    Accuse one politician apiece (7)        xxxxxxx
# 8           Twitch before at the top of the house (5)          xxxxx
# 9                          A length being planned (5)          xxxxx
# 10                            No he's been bright (5)          xxxxx
# 11              As the change was made in a hurry (5)          xxxxx
# 12   Orchestra was taken aback by cutting machine (7)        xxxxxxx
# 13        Exuberance produced by beastly drink? (6,7)  xxxxxxyyyyyyy
# 14         Cause delay in the one nearer the back (6)         xxxxxx
# 15      Concering drama in second game after draw (6)         xxxxxx
# 16  Lands it at last so it's not moving at all (2,...  xxyzzzzzzzzzz
# 17               Threat to workers by one in suit (6)         xxxxxx
# 18                                  A noted climb (5)          xxxxx
# 19                       Make cuts in the theatre (7)        xxxxxxx
# 20    Woman with hat made to look like sword case (6)         xxxxxx
# 21                   Humiliate because in Lincoln (5)          xxxxx
# 22                       Not straight like Oliver (6)         xxxxxx
# 23                                   One is sound (5)          xxxxx
#
#     prediction-9                             predicted_definition-9
# 0         MOJITO                                             liquor  \
# 1
# 2
# 3       PREENING                               trying to be stylish
# 4       INTERIMS                                   temporary leader
# 5          OREAL                       material that could be mined
# 6        CANDIES                                          sweetmeat
# 7        IMPEACH                                             accuse
# 8          ATTIC                                   top of the house
# 9           SPAN                                             length
# 10
# 11
# 12
# 13  ANIMALSPIRIT                                         exuberance
# 14        HANGUP                                        cause delay
# 15        REPLAY  a second game, typically following a drawn res...
# 16        SETTLE                                   lands it at last
# 17        LAYOFF                                  threat to workers
# 18        ASCENT                                      a noted climb
# 19       TRIMMER                                          make cuts
# 20        SHEATH                 hat made to look like a sword case
# 21         ABASE                                          humiliate
# 22       CROOKED                                       not straight
# 23
#
#                                            wordplay-9
# 0   MO (make needed) + JIT (youth leader) + O (par...  \
# 1
# 2
# 3           PRE (in a way) + EN (trying) + ING (way).
# 4                INTER (dramatic game) + IMS (leader)
# 5                ORE (mined material) + AL (could be)
# 6              MAN (male) + DIES (injured by vehicle)
# 7           I (one) + MP (politician) + EACH (apiece)
# 8                          AT (before) + TIC (twitch)
# 9                          S (being) + PLAN (planned)
# 10
# 11
# 12
# 13                  ANIMAL (beastly) + SPIRIT (drink)
# 14                  HANG (nearer the back) + UP (one)
# 15   RE (meaning concerning) + PLAY (a type of drama)
# 16                    SET (not moving) + TLE (at all)
# 17     LAY (one in suit, i.e. 'layperson') + OFF (by)
# 18         A (the indefinite article) + SCENT (climb)
# 19                          TRI (theatre) + MMER (in)
# 20                            SHE (woman) + ATH (hat)
# 21  A (because) + BASE (Lincoln, short for Lincoln...
# 22           COOKED (like Oliver, as in Oliver Twist)
# 23
#
#     consistent_decomposition-9  prediction_satisfies_constraints-9
# 0                         True                                True
# 1                         True                               False
# 2                         True                               False
# 3                         True                               False
# 4                         True                               False
# 5                         True                                True
# 6                        False                                True
# 7                         True                                True
# 8                         True                                True
# 9                        False                               False
# 10                        True                               False
# 11                        True                               False
# 12                        True                               False
# 13                        True                               False
# 14                        True                                True
# 15                        True                                True
# 16                        True                               False
# 17                        True                                True
# 18                        True                               False
# 19                        True                                True
# 20                        True                                True
# 21                        True                                True
# 22                       False                               False
# 23                        True                               False

# %% [markdown]
# I want to somehow use the validator columns to prioritise answers.
#
# I think it might be useful to push the dataframe to long form.

# %%
pred_cols = ["prediction", "predicted_definition", "wordplay"] + model.validator_names + ["prediction_satisfies_constraints"]

# %%
class SelfConsistencySelector:

    def __init__(self, validator_names):
        self.validator_names = validator_names

    def make_long_df(self, answer_df):
        pred_cols = [
            "prediction",
            "predicted_definition",
            "wordplay",
            "response",
        ] + self.validator_names + ["prediction_satisfies_constraints"]
        long_df = pd.wide_to_long(answer_df, pred_cols, i="rowid", j="index", sep="-")
        return long_df

    def select(self, answer_df):
        long_df = self.make_long_df(answer_df)
        query = ' & '.join(self.validator_names + ["prediction_satisfies_constraints"])
        filtered_df = long_df.query(query).reset_index()
        selected_df = filtered_df.groupby("rowid").head(1)
        return selected_df

# %%
for i in range(10):
    _def = answer_df[f'predicted_definition-{i}'].replace("\n", "").apply(lambda x: f" ({x}) - ")
    answer_df[f"output-{i}"] = answer_df[f"prediction-{i}"] +_def+ answer_df[f"wordplay-{i}"]

# %%
row_ids = [7, 0, 8, 20]
wp_cols = [c for c in answer_df.columns if c.startswith("output")][4:7]
wordplay_cols = [c for c in answer_df.columns if c.startswith("wordplay")][4:7]
prediction_cols = [c for c in answer_df.columns if c.startswith("prediction")][4:7]

# %%
ix = 1
pd.set_option('max_colwidth', 500)

display(answer_df[answer_df["rowid"] == row_ids[ix]][["clue"] + wp_cols])
# Out:
#                                                    clue
# 0  Liquor of particular make needed by youth leader (6)  \
#
#                                                                     output-4
# 0  MALTED (liquor) - MALT (particular make) + ED (youth leader, e.g. Edward)  \
#
#                                                                   output-5
# 0  BOURBON (liquor) - BON (particular make) + OUR (needed by youth leader)  \
#
#                                                        output-6
# 0  BRANDY (liquor) - BRAND (particular make) + Y (youth leader)

# %%
pd.set_option('max_colwidth', 800)
answer_df[answer_df["rowid"].isin([7, 0, 8, 20])][["clue"] + wordplay_cols]
# Out:
#                                                     clue
# 0   Liquor of particular make needed by youth leader (6)  \
# 7                       Accuse one politician apiece (7)
# 8              Twitch before at the top of the house (5)
# 20       Woman with hat made to look like sword case (6)
#
#                                                  wordplay-4
# 0   MALT (particular make) + ED (youth leader, e.g. Edward)  \
# 7                 I (one) + MP (politician) + EACH (apiece)
# 8                                AT (before) + TIC (twitch)
# 20                                SCAR (woman) + BARD (hat)
#
#                                               wordplay-5
# 0   BON (particular make) + OUR (needed by youth leader)  \
# 7             I (one) + MP (politician) + EACH (apiece).
# 8                             AT (before) + TIC (twitch)
# 20  SCAB (woman) + BARD (hat, as in the 'bard' of a hat)
#
#                                                 wordplay-6
# 0               BRAND (particular make) + Y (youth leader)
# 7                I (one) + MP (politician) + EACH (apiece)
# 8                               AT (before) + TIC (twitch)
# 20  SHE (woman) + ATH (made to look like, 'hat' backwards)

# %%
selector = SelfConsistencySelector(model.validator_names)

# %%
long_df = selector.make_long_df(answer_df)
query = ' & '.join(model.validator_names + ["prediction_satisfies_constraints"])
filtered_df = long_df.query(query).reset_index()

# %%
cutoff = 9

# %%
gdf = pd.DataFrame(filtered_df.groupby("rowid")["prediction"].value_counts()).sort_values(["count", "rowid"], ascending=False)

# %%
gdf
# Out:
#                   count
# rowid prediction
# 12    BANDSAW        10
# 8     ATTIC          10
# 7     IMPEACH        10
# 21    ABASE           9
# 15    REPLAY          9
# 19    TRIMMER         8
# 14    HOLDUP          8
# 17    STRIKE          4
# 0     BRANDY          4
# 20    SHEATH          3
# 17    UNIONS          3
# 23    AUDIO           2
# 14    HINDER          2
# 6     CANDIES         2
# 5     OREAL           2
# 23    ONSET           1
# 17    LAYOFF          1
# 11    SWAPT           1
# 6     MENDOZA         1
#       MAMMOTH         1
# 5     OREME           1
# 1     SMITHY          1
#       AVIARY          1
# 0     MALTED          1

# %%
selected_rows = gdf[gdf["count"]>=cutoff].reset_index()["rowid"].values

# %%
selected_rows
# Out:
# array([12,  8,  7, 21, 15])

# %%
selected = selector.select(answer_df)

# %%
selected
# Out:
#     rowid  index  starty num_letters
# 0       7      0       1           7  \
# 1       8      0       5           5
# 2      12      0       9           7
# 3      14      0      13           6
# 4      15      0      13           6
# 5      21      0       8           5
# 6       0      1       1           6
# 7       1      1       1           6
# 8       5      1       1           5
# 14     17      1       1           6
# 15     19      1       7           7
# 16     20      1       8           6
# 18     23      1       9           5
# 19      6      2       5           7
# 22     11      2       9           5
#
#                                                  clue   answer  startx
# 0                    Accuse one politician apiece (7)  IMPEACH       9  \
# 1           Twitch before at the top of the house (5)    ATTIC       9
# 2    Orchestra was taken aback by cutting machine (7)  BANDSAW       7
# 3          Cause delay in the one nearer the back (6)   HOLDUP       1
# 4       Concering drama in second game after draw (6)   REPLAY       8
# 5                    Humiliate because in Lincoln (5)    ABASE       7
# 6   Liquor of particular make needed by youth lead...   BRANDY       1
# 7   Not the HQ of Britain's capital stockbreeding ...   AVIARY       1
# 8                    Material that could be mined (5)    OREAL       5
# 14               Threat to workers by one in suit (6)   STRIKE      13
# 15                       Make cuts in the theatre (7)  TRIMMER       5
# 16    Woman with hat made to look like sword case (6)   SHEATH       1
# 18                                   One is sound (5)    ONSET       9
# 19           Sweetmeat of male injured by vehicle (7)  MENDOZA       1
# 22              As the change was made in a hurry (5)    SWAPT       1
#
#     num_correct orientation  position  correct prediction
# 0             0        down         5    False    IMPEACH  \
# 1             0      across        11    False      ATTIC
# 2             0      across        19    False    BANDSAW
# 3             0      across        22    False     HOLDUP
# 4             0      across        23    False     REPLAY
# 5             0        down        16    False      ABASE
# 6             0      across         1    False     BRANDY
# 7             0        down         1    False     AVIARY
# 8             0        down         3    False      OREAL
# 14            0        down         7    False     STRIKE
# 15            0        down        13    False    TRIMMER
# 16            0        down        15    False     SHEATH
# 18            0        down        20    False      ONSET
# 19            0      across        10    False    MENDOZA
# 22            0      across        18    False      SWAPT
#
#                                  predicted_definition
# 0                                              accuse  \
# 1                                       twitch before
# 2                                     cutting machine
# 3                                         cause delay
# 4   a second game, typically following a drawn res...
# 5                                           humiliate
# 6                                              liquor
# 7                     not the HQ of Britain's capital
# 8                        Material that could be mined
# 14                                  threat to workers
# 15                                          make cuts
# 16                   hat made to look like sword case
# 18                                                one
# 19                                          sweetmeat
# 22                             change made in a hurry
#
#                                              wordplay
# 0           I (one) + MP (politician) + EACH (apiece)  \
# 1                    AT (at) + TIC (top of the house)
# 2   BAND (orchestra) + SAW (was, 'taken aback' i.e...
# 3          HOLD (the one nearer the back) + UP (back)
# 4    RE (meaning concerning) + PLAY (a type of drama)
# 5      A (because) + BASE (Lincoln, a city in the UK)
# 6          BRAN (youth leader) + DY (particular make)
# 7   A (not) + VI (Roman numeral for 6) + ARY (stoc...
# 8                         ORE (mined) + AL (could be)
# 14                 S (one) + TR (suit) + IKE (threat)
# 15                          TRI (theatre) + MMER (in)
# 16              SHE (woman) + ATH (made to look like)
# 18                              ON (sound) + SET (is)
# 19           MEN (male) + DO (injured) + ZA (vehicle)
# 22                          SWAP (change) + T (hurry)
#
#                                              response
# 0   Answer: IMPEACH (accuse) - I (one) + MP (polit...  \
# 1   \nAnswer: ATTIC (twitch before) - AT (at) + TI...
# 2   \nAnswer: BANDSAW (cutting machine) - BAND (or...
# 3   \nAnswer: HOLDUP (cause delay) - HOLD (the one...
# 4   \nAnswer: REPLAY (a second game, typically fol...
# 5   \nAnswer: ABASE (humiliate) - A (because) + BA...
# 6   \nAnswer: BRANDY (liquor) - BRAN (youth leader...
# 7   \nAnswer: AVIARY (not the HQ of Britain's capi...
# 8   \nAnswer: OREAL (Material that could be mined)...
# 14  \nAnswer: STRIKE (threat to workers) - S (one)...
# 15  \nAnswer: TRIMMER (make cuts) - TRI (theatre) ...
# 16  \nAnswer: SHEATH (hat made to look like sword ...
# 18      \nAnswer: ONSET (one) - ON (sound) + SET (is)
# 19  \nAnswer: MENDOZA (sweetmeat) - MEN (male) + D...
# 22  \nAnswer: SWAPT (change made in a hurry) - SWA...
#
#     consistent_decomposition  prediction_satisfies_constraints
# 0                       True                              True
# 1                       True                              True
# 2                       True                              True
# 3                       True                              True
# 4                       True                              True
# 5                       True                              True
# 6                       True                              True
# 7                       True                              True
# 8                       True                              True
# 14                      True                              True
# 15                      True                              True
# 16                      True                              True
# 18                      True                              True
# 19                      True                              True
# 22                      True                              True

# %%
output_cols = ["clue", "answer", "startx", "starty", "position", "orientation"]
selected["answer"] = selected["prediction"].apply(lambda x: x.replace(" ", ""))
selected[output_cols].to_json("website/answers1.json", orient="records", indent=4)

# %%
len(answer_df), answer_df["correct"].sum()
# Out:
# (23, 8)

# %%
pd.read_json("website/crosswordData.json")
# Out:
#                                                  clue         answer  startx
# 0    Liquor of particular make needed by youth leader         xxxxxx       1  \
# 1   Not the HQ of Britain's capital stockbreeding ...         xxxxxx       1
# 2                    Amputate limbs to remove weapons         xxxxxx       8
# 3                       Trying to be stylish in a way  xxxxxyzzzzzzz       3
# 4                   Temporary leader in dramatic game  xxxxxxyyyyyyy       1
# 5                        Material that could be mined          xxxxx       5
# 6                Sweetmeat of male injured by vehicle        xxxxxxx       1
# 7                        Accuse one politician apiece        xxxxxxx       9
# 8               Twitch before at the top of the house          xxxxx       9
# 9                              A length being planned          xxxxx       2
# 10                                No he's been bright          xxxxx       8
# 11                  As the change was made in a hurry          xxxxx       1
# 12       Orchestra was taken aback by cutting machine        xxxxxxx       7
# 13              Exuberance produced by beastly drink?  xxxxxxyyyyyyy       1
# 14             Cause delay in the one nearer the back         xxxxxx       1
# 15          Concering drama in second game after draw         xxxxxx       8
# 16         Lands it at last so it's not moving at all  xxyzzzzzzzzzz      11
# 17                   Threat to workers by one in suit         xxxxxx      13
# 18                                      A noted climb          xxxxx       7
# 19                           Make cuts in the theatre        xxxxxxx       5
# 20        Woman with hat made to look like sword case         xxxxxx       1
# 21                       Humiliate because in Lincoln          xxxxx       7
# 22                           Not straight like Oliver         xxxxxx      13
# 23                                       One is sound          xxxxx       9
#
#     starty  position orientation
# 0        1         1      across
# 1        1         1        down
# 2        1         4      across
# 3        1         2        down
# 4        3         9      across
# 5        1         3        down
# 6        5        10      across
# 7        1         5        down
# 8        5        11      across
# 9        7        12      across
# 10       7        14      across
# 11       9        18      across
# 12       9        19      across
# 13      11        21      across
# 14      13        22      across
# 15      13        23      across
# 16       1         6        down
# 17       1         7        down
# 18       2         8        down
# 19       7        13        down
# 20       8        15        down
# 21       8        16        down
# 22       8        17        down
# 23       9        20        down

# %%
answer_df
# Out:
#     rowid                                               clue         answer
# 0      88      Intrepid daughter missing parent's sister (9)      DAUNTLESS  \
# 2      90       Training device transforming Liam's tour (9)      SIMULATOR
# 3      91                  Plant serving sauce with meat (5)          OXLIP
# 4      92          Clothing submerged in northern river? (9)      UNDERWEAR
# 5      93                     Popular act, without doubt (6)         INDEED
# 6      94           Position of rubbish in South America (6)         STATUS
# 7      95  Element Mendeleev originally found in flowerin...      GERMANIUM
# 8      96      Head of police called, revealing accident (5)          PRANG
# 9      97                       Switch posts near ground (9)      TRANSPOSE
# 10     98  With cunning, son locates youth leaders twice (5)          SLYLY
# 11     99  Stun factory, displaying alyssum, for example ...     ROCK PLANT
# 12    100   Argument inspector advanced in Home Counties (7)        DISPUTE
# 13    101    Destroyed a Parisian serving-girl verbally? (6)         UNMADE
# 14    102                   Roofer left in middle or row (5)          TILER
# 15    103             Amphibian originally eaten for tea (3)            EFT
# 16    104    Unexpectedly grumpy about quiet revolution (12)   SURPRISINGLY
# 17    105  One making meteoric progress at Bisley, say? (...  SHOOTING STAR
# 18    106               Insular type this writer maligns (8)       ISLANDER
# 19    107                 Plea to dine among competitors (8)       ENTREATY
# 20    108  Storm created by English politician during tri...        TEMPEST
# 21    109  Shrub found in Michigan, Missouri and South Am...         MIMOSA
# 22    110              Model put up by a fabulous writer (5)          AESOP
# 23    111             Part of circle a churchgoer joined (3)            ARC
#
#                       definition clue_number puzzle_date
# 0                       Intrepid          1a  2020-09-29  \
# 2                Training device          8a  2020-09-29
# 3                          Plant          9a  2020-09-29
# 4                       Clothing         10a  2020-09-29
# 5                  without doubt         12a  2020-09-29
# 6                       Position         13a  2020-09-29
# 7                        Element         16a  2020-09-29
# 8                       accident         18a  2020-09-29
# 9                         Switch         19a  2020-09-29
# 10                  With cunning         21a  2020-09-29
# 11          alyssum, for example         22a  2020-09-29
# 12                      Argument          1d  2020-09-29
# 13                     Destroyed          2d  2020-09-29
# 14                        Roofer          3d  2020-09-29
# 15                     Amphibian          4d  2020-09-29
# 16                  Unexpectedly          5d  2020-09-29
# 17  One making meteoric progress          6d  2020-09-29
# 18                  Insular type          7d  2020-09-29
# 19                          Plea         11d  2020-09-29
# 20                         Storm         14d  2020-09-29
# 21                         Shrub         15d  2020-09-29
# 22               fabulous writer         17d  2020-09-29
# 23                Part of circle         20d  2020-09-29
#
#                  puzzle_name
# 0   Times Quick Cryptic 1711  \
# 2   Times Quick Cryptic 1711
# 3   Times Quick Cryptic 1711
# 4   Times Quick Cryptic 1711
# 5   Times Quick Cryptic 1711
# 6   Times Quick Cryptic 1711
# 7   Times Quick Cryptic 1711
# 8   Times Quick Cryptic 1711
# 9   Times Quick Cryptic 1711
# 10  Times Quick Cryptic 1711
# 11  Times Quick Cryptic 1711
# 12  Times Quick Cryptic 1711
# 13  Times Quick Cryptic 1711
# 14  Times Quick Cryptic 1711
# 15  Times Quick Cryptic 1711
# 16  Times Quick Cryptic 1711
# 17  Times Quick Cryptic 1711
# 18  Times Quick Cryptic 1711
# 19  Times Quick Cryptic 1711
# 20  Times Quick Cryptic 1711
# 21  Times Quick Cryptic 1711
# 22  Times Quick Cryptic 1711
# 23  Times Quick Cryptic 1711
#
#                                            source_url           source
# 0   https://times-xwd-times.livejournal.com/241434...  times_xwd_times  \
# 2   https://times-xwd-times.livejournal.com/241434...  times_xwd_times
# 3   https://times-xwd-times.livejournal.com/241434...  times_xwd_times
# 4   https://times-xwd-times.livejournal.com/241434...  times_xwd_times
# 5   https://times-xwd-times.livejournal.com/241434...  times_xwd_times
# 6   https://times-xwd-times.livejournal.com/241434...  times_xwd_times
# 7   https://times-xwd-times.livejournal.com/241434...  times_xwd_times
# 8   https://times-xwd-times.livejournal.com/241434...  times_xwd_times
# 9   https://times-xwd-times.livejournal.com/241434...  times_xwd_times
# 10  https://times-xwd-times.livejournal.com/241434...  times_xwd_times
# 11  https://times-xwd-times.livejournal.com/241434...  times_xwd_times
# 12  https://times-xwd-times.livejournal.com/241434...  times_xwd_times
# 13  https://times-xwd-times.livejournal.com/241434...  times_xwd_times
# 14  https://times-xwd-times.livejournal.com/241434...  times_xwd_times
# 15  https://times-xwd-times.livejournal.com/241434...  times_xwd_times
# 16  https://times-xwd-times.livejournal.com/241434...  times_xwd_times
# 17  https://times-xwd-times.livejournal.com/241434...  times_xwd_times
# 18  https://times-xwd-times.livejournal.com/241434...  times_xwd_times
# 19  https://times-xwd-times.livejournal.com/241434...  times_xwd_times
# 20  https://times-xwd-times.livejournal.com/241434...  times_xwd_times
# 21  https://times-xwd-times.livejournal.com/241434...  times_xwd_times
# 22  https://times-xwd-times.livejournal.com/241434...  times_xwd_times
# 23  https://times-xwd-times.livejournal.com/241434...  times_xwd_times
#
#    num_letters  ... prediction_satisfies_constraints-1
# 0            9  ...                              False  \
# 2            9  ...                               True
# 3            5  ...                               True
# 4            9  ...                              False
# 5            6  ...                               True
# 6            6  ...                              False
# 7            9  ...                               True
# 8            5  ...                              False
# 9            9  ...                              False
# 10           5  ...                              False
# 11      (4, 5)  ...                              False
# 12           7  ...                              False
# 13           6  ...                               True
# 14           5  ...                               True
# 15           3  ...                              False
# 16          12  ...                              False
# 17      (8, 4)  ...                              False
# 18           8  ...                               True
# 19           8  ...                              False
# 20           7  ...                              False
# 21           6  ...                              False
# 22           5  ...                              False
# 23           3  ...                               True
#
#    prediction_satisfies_constraints-2 prediction_satisfies_constraints-3
# 0                               False                              False  \
# 2                                True                               True
# 3                                True                               True
# 4                               False                              False
# 5                               False                               True
# 6                               False                              False
# 7                                True                               True
# 8                                True                              False
# 9                               False                              False
# 10                               True                              False
# 11                              False                              False
# 12                              False                              False
# 13                               True                               True
# 14                               True                               True
# 15                              False                              False
# 16                               True                               True
# 17                               True                               True
# 18                               True                               True
# 19                               True                               True
# 20                              False                               True
# 21                               True                               True
# 22                              False                               True
# 23                               True                              False
#
#    prediction_satisfies_constraints-4 prediction_satisfies_constraints-5
# 0                                True                               True  \
# 2                                True                               True
# 3                                True                               True
# 4                               False                              False
# 5                               False                               True
# 6                               False                              False
# 7                                True                               True
# 8                               False                              False
# 9                               False                              False
# 10                               True                              False
# 11                              False                              False
# 12                              False                               True
# 13                               True                              False
# 14                               True                               True
# 15                              False                              False
# 16                               True                               True
# 17                              False                              False
# 18                               True                              False
# 19                               True                               True
# 20                               True                              False
# 21                              False                              False
# 22                              False                               True
# 23                               True                               True
#
#    prediction_satisfies_constraints-6 prediction_satisfies_constraints-7
# 0                                True                              False  \
# 2                                True                               True
# 3                               False                               True
# 4                               False                              False
# 5                                True                              False
# 6                               False                              False
# 7                                True                               True
# 8                               False                              False
# 9                               False                              False
# 10                              False                              False
# 11                              False                              False
# 12                              False                               True
# 13                              False                              False
# 14                               True                               True
# 15                              False                              False
# 16                               True                               True
# 17                               True                              False
# 18                               True                               True
# 19                               True                              False
# 20                              False                               True
# 21                               True                               True
# 22                               True                               True
# 23                               True                              False
#
#    prediction_satisfies_constraints-8 prediction_satisfies_constraints-9
# 0                                True                              False  \
# 2                                True                               True
# 3                                True                               True
# 4                               False                              False
# 5                               False                               True
# 6                               False                              False
# 7                                True                               True
# 8                               False                              False
# 9                               False                              False
# 10                              False                              False
# 11                              False                              False
# 12                              False                              False
# 13                               True                              False
# 14                              False                              False
# 15                              False                              False
# 16                              False                               True
# 17                               True                               True
# 18                               True                               True
# 19                               True                              False
# 20                              False                              False
# 21                               True                               True
# 22                              False                              False
# 23                               True                               True
#
#    correct
# 0     True
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# 10   False
# 11   False
# 12   False
# 13   False
# 14   False
# 15   False
# 16    True
# 17    True
# 18    True
# 19    True
# 20   False
# 21    True
# 22   False
# 23    True
#
# [23 rows x 61 columns]
