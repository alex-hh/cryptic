# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from cryptic.evaluation import models, evaluations

# %%
evaluation = evaluations.get("Page1Example")
model = models.get("RandomString")

# %%
evaluation.qa_frame.df.sample(5)
# Out:
#      rowid                                              clue   answer  \
# 867    868             Bird’s to raise hatch, reportedly (7)  JACKDAW
# 432    433  I'm taken aback by anger? That's an illusion (6)   MIRAGE
# 642    643  Closely follow play, having to put in notice (6)   SHADOW
# 174    175     Eroded around front of ship — not so good (5)    WORSE
# 443    444          Province in actual centre of Germany (5)    REALM
#
#          definition clue_number puzzle_date              puzzle_name  \
# 867            Bird         43d  2020-06-13               Jumbo 1443
# 432        illusion         13a  2016-03-28        Quick Cryptic 535
# 642  Closely follow         35a  2017-02-25               Jumbo 1250
# 174             NaN         10a  2017-11-13  Times Quick Cryptic 960
# 443        Province          4d  2016-03-28        Quick Cryptic 535
#
#                                             source_url           source  \
# 867  https://times-xwd-times.livejournal.com/235507...  times_xwd_times
# 432  https://times-xwd-times.livejournal.com/149223...  times_xwd_times
# 642  https://times-xwd-times.livejournal.com/169221...  times_xwd_times
# 174  https://times-xwd-times.livejournal.com/184243...  times_xwd_times
# 443  https://times-xwd-times.livejournal.com/149223...  times_xwd_times
#
#     num_letters
# 867           7
# 432           6
# 642           6
# 174           5
# 443           5

# %%
metrics, answers_df = evaluation.run(model)

# %%
answers_df
# Out:
#      rowid                                               clue  \
# 0        1                 Acquisitive chap, as we see it (8)
# 1        2             Back yard fencing weak and sagging (6)
# 2        3  Stripping off uniform, love holding colonel's ...
# 3        4     Without a mark where they should be gained (4)
# 4        5  Put a stop to Rugby's foul school leader (5,2,...
# ..     ...                                                ...
# 995    996              Unruffled sound from cow in south (6)
# 996    997  Having climbed moor? That is right, it’s more ...
# 997    998  Tipping hat, one overseeing man, hard-working (8)
# 998    999  Nasty stain mars a chair arm initially — prote...
# 999   1000                   MP should get back in here (4,4)
#
#                 answer                   definition clue_number puzzle_date  \
# 0             COVETOUS                  Acquisitive          1a  2019-08-08
# 1               DROOPY                      sagging          5a  2019-08-08
# 2           UNCLOTHING                    Stripping          8a  2019-08-08
# 3                 EXAM  where they should be gained          9a  2019-08-08
# 4    KNOCK ON THE HEAD                Put a stop to         10a  2019-08-08
# ..                 ...                          ...         ...         ...
# 995             SMOOTH                    Unruffled          4d  2019-02-25
# 996            ROOMIER                more spacious          6d  2019-02-25
# 997           DILIGENT                 hard-working          7d  2019-02-25
# 998       ANTIMACASSAR             protective cloth          8d  2019-02-25
# 999          SAFE SEAT   MP should get back in here         12d  2019-02-25
#
#      puzzle_name                                         source_url  \
# 0    Times 27424  https://times-xwd-times.livejournal.com/218581...
# 1    Times 27424  https://times-xwd-times.livejournal.com/218581...
# 2    Times 27424  https://times-xwd-times.livejournal.com/218581...
# 3    Times 27424  https://times-xwd-times.livejournal.com/218581...
# 4    Times 27424  https://times-xwd-times.livejournal.com/218581...
# ..           ...                                                ...
# 995      QC 1295  https://times-xwd-times.livejournal.com/209587...
# 996      QC 1295  https://times-xwd-times.livejournal.com/209587...
# 997      QC 1295  https://times-xwd-times.livejournal.com/209587...
# 998      QC 1295  https://times-xwd-times.livejournal.com/209587...
# 999      QC 1295  https://times-xwd-times.livejournal.com/209587...
#
#               source   num_letters       prediction_0  correct
# 0    times_xwd_times             8           VUUFFJOD    False
# 1    times_xwd_times             6             FRHNXL    False
# 2    times_xwd_times            10         HTEAPDDEFM    False
# 3    times_xwd_times             4               INUY    False
# 4    times_xwd_times  (5, 2, 3, 4)  AZKYN YM MSC LDFT    False
# ..               ...           ...                ...      ...
# 995  times_xwd_times             6             LNYRNT    False
# 996  times_xwd_times             7            ZMRFWPB    False
# 997  times_xwd_times             8           SVMREFST    False
# 998  times_xwd_times            12       XYDPUKGEFVTC    False
# 999  times_xwd_times        (4, 4)          AMRU UEDH    False
#
# [1000 rows x 12 columns]
